# %% [markdown]
# # Cleansing
# ---

# %% [markdown]
# <br/>
#
# ### Exercise 1
#
# **Write a Python function to remove all non-alphanumeric characters from a string.**
#
# <br/>
#
#
# To remove all non-alphanumeric characters from a string in Python, use the filter() method. The filter() is a built-in Python method that extracts items from an iterable-like string for which a function returns True. The isalnum() is a built-in Python method that returns True if all characters in the String are alphanumeric (either alphabets or numbers). If not, it returns False. (pythonsolved.com)

# %%
inputString = "Is your email id jay_me58@gmail.com?"
outputString = ''.join(filter(str.isalnum, inputString))
print(outputString)
# Out:
# Isyouremailidjayme58gmailcom

# %% [markdown]
# <br/>
# You can see from the output above that the input string had non-alphanumeric characters, but after using the filter() function with isalnum() and join() method, we removed all the special characters from the String.

# %% [markdown]
# ---

# %% [markdown]
# <br/>
#
# ### Exercise 2
#
# **Adapt the code to capitalise the first letter of the iris species, using regular expressions.**

# %% [markdown]
# For reference, we are being asked to adapt code that was written in our lecture notes for Cleansing. So the code I have adapted has been copied and pasted from Ians Jupyter notes.

# %%
# Ians class notes

import urllib.request
import re

url = r'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

iris = [line.decode('utf-8').strip() for line in urllib.request.urlopen(url)]

iris
# Out:
# ['5.1,3.5,1.4,0.2,Iris-setosa',
#  '4.9,3.0,1.4,0.2,Iris-setosa',
#  '4.7,3.2,1.3,0.2,Iris-setosa',
#  '4.6,3.1,1.5,0.2,Iris-setosa',
#  '5.0,3.6,1.4,0.2,Iris-setosa',
#  '5.4,3.9,1.7,0.4,Iris-setosa',
#  '4.6,3.4,1.4,0.3,Iris-setosa',
#  '5.0,3.4,1.5,0.2,Iris-setosa',
#  '4.4,2.9,1.4,0.2,Iris-setosa',
#  '4.9,3.1,1.5,0.1,Iris-setosa',
#  '5.4,3.7,1.5,0.2,Iris-setosa',
#  '4.8,3.4,1.6,0.2,Iris-setosa',
#  '4.8,3.0,1.4,0.1,Iris-setosa',
#  '4.3,3.0,1.1,0.1,Iris-setosa',
#  '5.8,4.0,1.2,0.2,Iris-setosa',
#  '5.7,4.4,1.5,0.4,Iris-setosa',
#  '5.4,3.9,1.3,0.4,Iris-setosa',
#  '5.1,3.5,1.4,0.3,Iris-setosa',
#  '5.7,3.8,1.7,0.3,Iris-setosa',
#  '5.1,3.8,1.5,0.3,Iris-setosa',
#  '5.4,3.4,1.7,0.2,Iris-setosa',
#  '5.1,3.7,1.5,0.4,Iris-setosa',
#  '4.6,3.6,1.0,0.2,Iris-setosa',
#  '5.1,3.3,1.7,0.5,Iris-setosa',
#  '4.8,3.4,1.9,0.2,Iris-setosa',
#  '5.0,3.0,1.6,0.2,Iris-setosa',
#  '5.0,3.4,1.6,0.4,Iris-setosa',
#  '5.2,3.5,1.5,0.2,Iris-setosa',
#  '5.2,3.4,1.4,0.2,Iris-setosa',
# ...

# %%
# recompile the information, removing the word iris and reversing the information so the species comes first

strip_iris = re.compile(r'([0-9]\.[0-9]),([0-9]\.[0-9]),([0-9]\.[0-9]),([0-9]\.[0-9]),Iris-([a-z]+)')

Iris2 = [strip_iris.sub(r'\5,\4,\3,\2,\1', line) for line in iris if line]

# rename the new output as Iris2
Iris2
# Out:
# ['setosa,0.2,1.4,3.5,5.1',
#  'setosa,0.2,1.4,3.0,4.9',
#  'setosa,0.2,1.3,3.2,4.7',
#  'setosa,0.2,1.5,3.1,4.6',
#  'setosa,0.2,1.4,3.6,5.0',
#  'setosa,0.4,1.7,3.9,5.4',
#  'setosa,0.3,1.4,3.4,4.6',
#  'setosa,0.2,1.5,3.4,5.0',
#  'setosa,0.2,1.4,2.9,4.4',
#  'setosa,0.1,1.5,3.1,4.9',
#  'setosa,0.2,1.5,3.7,5.4',
#  'setosa,0.2,1.6,3.4,4.8',
#  'setosa,0.1,1.4,3.0,4.8',
#  'setosa,0.1,1.1,3.0,4.3',
#  'setosa,0.2,1.2,4.0,5.8',
#  'setosa,0.4,1.5,4.4,5.7',
#  'setosa,0.4,1.3,3.9,5.4',
#  'setosa,0.3,1.4,3.5,5.1',
#  'setosa,0.3,1.7,3.8,5.7',
#  'setosa,0.3,1.5,3.8,5.1',
#  'setosa,0.2,1.7,3.4,5.4',
#  'setosa,0.4,1.5,3.7,5.1',
#  'setosa,0.2,1.0,3.6,4.6',
#  'setosa,0.5,1.7,3.3,5.1',
#  'setosa,0.2,1.9,3.4,4.8',
#  'setosa,0.2,1.6,3.0,5.0',
#  'setosa,0.4,1.6,3.4,5.0',
#  'setosa,0.2,1.5,3.5,5.2',
#  'setosa,0.2,1.4,3.4,5.2',
#  'setosa,0.2,1.6,3.2,4.7',
#  'setosa,0.2,1.6,3.1,4.8',
#  'setosa,0.4,1.5,3.4,5.4',
#  'setosa,0.1,1.5,4.1,5.2',
#  'setosa,0.2,1.4,4.2,5.5',
# ...

# %%
def convert_into_uppercase(a):
    return a.group(1) + a.group(2).upper()

Irisnew = [re.sub("(^|\s)(\S)", convert_into_uppercase, line) for line in Iris2 if line]

Irisnew
# Out:
# ['Setosa,0.2,1.4,3.5,5.1',
#  'Setosa,0.2,1.4,3.0,4.9',
#  'Setosa,0.2,1.3,3.2,4.7',
#  'Setosa,0.2,1.5,3.1,4.6',
#  'Setosa,0.2,1.4,3.6,5.0',
#  'Setosa,0.4,1.7,3.9,5.4',
#  'Setosa,0.3,1.4,3.4,4.6',
#  'Setosa,0.2,1.5,3.4,5.0',
#  'Setosa,0.2,1.4,2.9,4.4',
#  'Setosa,0.1,1.5,3.1,4.9',
#  'Setosa,0.2,1.5,3.7,5.4',
#  'Setosa,0.2,1.6,3.4,4.8',
#  'Setosa,0.1,1.4,3.0,4.8',
#  'Setosa,0.1,1.1,3.0,4.3',
#  'Setosa,0.2,1.2,4.0,5.8',
#  'Setosa,0.4,1.5,4.4,5.7',
#  'Setosa,0.4,1.3,3.9,5.4',
#  'Setosa,0.3,1.4,3.5,5.1',
#  'Setosa,0.3,1.7,3.8,5.7',
#  'Setosa,0.3,1.5,3.8,5.1',
#  'Setosa,0.2,1.7,3.4,5.4',
#  'Setosa,0.4,1.5,3.7,5.1',
#  'Setosa,0.2,1.0,3.6,4.6',
#  'Setosa,0.5,1.7,3.3,5.1',
#  'Setosa,0.2,1.9,3.4,4.8',
#  'Setosa,0.2,1.6,3.0,5.0',
#  'Setosa,0.4,1.6,3.4,5.0',
#  'Setosa,0.2,1.5,3.5,5.2',
#  'Setosa,0.2,1.4,3.4,5.2',
#  'Setosa,0.2,1.6,3.2,4.7',
#  'Setosa,0.2,1.6,3.1,4.8',
#  'Setosa,0.4,1.5,3.4,5.4',
#  'Setosa,0.1,1.5,4.1,5.2',
#  'Setosa,0.2,1.4,4.2,5.5',
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### References
#
# [1] https://pythonsolved.com/how-to-remove-all-non-alphanumeric-characters-from-string-in-python/#:~:text=To%20remove%20all%20non-alphanumeric%20characters%20from%20a%20string,iterable-like%20string%20for%20which%20a%20function%20returns%20True.
# <br/>
#
# [2] https://github.com/ianmcloughlin/2223-S1-fund-data-analysis/blob/main/notebooks/05-cleansing.ipynb
#
# [3] https://www.geeksforgeeks.org/python-program-to-capitalize-the-first-letter-of-every-word-in-the-file/
#
# [4] https://favtutor.com/blogs/capitalize-first-letter-python
#
# [5] https://thispointer.com/python-capitalize-the-first-letter-of-each-word-in-a-string/#:~:text=Use%20title%20%28%29%20to%20capitalize%20the%20first%20letter,all%20remaining%20characters%20of%20word%20to%20lower%20case.
#
# [6] https://stackoverflow.com/questions/66238087/using-re-sub-to-capitalize-a-pattern-and-add-some-text-before-that-pattern
